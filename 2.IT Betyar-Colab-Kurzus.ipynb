# %% [markdown]
# <h1><font color='lightblue'><b>Google Colab Kurzus 2. </b> |  itbetyar.hu</font></h1>
#
# <img src="https://www.itbetyar.hu/dload_itb/itb_logo70.webp" alt="IT Betyár" width="60">
# <img src="https://drive.google.com/uc?export=view&id=1W7LuoRWg6zLwAS0z9r6RKli_ANOveo6B" width="93">
#
# <br>
#
# <div>
# <h3>Várunk szeretettel képzéseinken:</h3>
#   <a href="https://itbetyar.hu"><img alt="IT Betyár honlap" src="https://itbetyar.hu/dload_itb/colab_gomb_itb.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/python-tanfolyam/"><img alt="IT Betyár honlap" src="https://itbetyar.hu/dload_itb/colab_gomb_kpt.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/uzleti-a-i-automatizacio-workshop/"><img alt="IT Betyár honlap" src="https://itbetyar.hu/dload_itb/colab_gomb_aiaut.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/mesterseges-intelligencia-fejleszto-tanfolyam/"><img alt="AI Developer tanfolyam" src="https://itbetyar.hu/dload_itb/colab_gomb_aidev.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/sql-tanfolyam/"><img alt="SQL Képzések" src="https://itbetyar.hu/dload_itb/colab_gomb_sql.webp" height="30px"></a>
#
# <h3>Social IT oldalak - Kód kohók:</h3>
#   <a href="https://huggingface.co/itbetyar"><img alt="Hugging Face oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_hugging.webp" height="30px"></a>
#   <a href="https://github.com/itbetyar"><img alt="Github oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_github.webp" height="30px"></a>
#   <a href="https://www.kaggle.com/itbetyar"><img alt="Kaggle oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_kaggle.webp" height="30px"></a>
#   <a href="https://www.youtube.com/@itbetyar"><img alt="Kaggle oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_youtube.webp" height="30px"></a>
# </div>
#
# <br>
#
# ---
# <br>
#
# <h1><font color='orange'>3/2-es lecke : <b>Google Colab haladóbb gyakorlat</b></font></h1>
#
# - Az első lépések után, jól használható tudnivalók
#
# <br>
# <br>
#
# ---

# %% [markdown]
# ## 1. GPU - CPU kérdések átváltás
# - CPU - Central Processing Unit
# - GPU - Graphical Processing Unit
# Utóbbi lényegesen nagyobb számítási teljesítményre képes.
#
# Menü >> Runtime >> Change runtime type

# %%
# GPU - CPU kérdések átváltás

# %% [markdown]
# ## 2. A Variable inspector
# - Változók értékének nyomon követése
# - Futtasd alábbi kód mezőt és nézd meg a `variable inspectort`

# %%
x = 42 # egész szám változó létrehozása

szoveg = "Macskafogó" # szöveg típusó változó létrehozása

logikai_ertek = True  # logikai érték létrehozása

# %% [markdown]
# Alábbi kód futtatásával módosítjuk a változóink értékeit!
# Kövesd ezt figyelemmel a `variable inspector` ablakban

# %%
x = 222

szoveg = "Grabovsky"

# %% [markdown]
# ## 3. Python Library telepítése
# - Nagyon sok library már telepítve van
# - Ami nincs az telepíthető a `!pip install libraryneve` paranccsal

# %%
# !pip install google-generativeai

# %% [markdown]
# ## 4. A `Run before` parancs

# %%
if logikai_ertek:
    print("A logikai érték tartalma IGAZ")
else:
    print("A logikai érték tartalma HAMIS")

# %% [markdown]
# Alább egy xy minikód a `run before` teszteléséhez

# %%
print(type(x))

if isinstance(x, int):
    print("X egy egész szám típusű változó")

# %% [markdown]
# ### Beállítások
# - Tools -> Settings

# %%
# Cella opciókat is nézzük meg

# %% [markdown]
# ### A kultúrált kilépés
# - Disconnect and delete runtime

# %%
# Disconnect and delete runtime

# %% [markdown]
# ---
# ### **A lecke végére értél, gratulálok a sikeres lecketeljesítéshez!** <br>
#
# <h1><font color='lightblue'>Google Colab - Mini kurzus 2.</font></h1>
#
# <img src="https://www.itbetyar.hu/dload_itb/itb_logo70.webp" alt="IT Betyár" width="60">
#
# <br>
# <div>
# <h3>Várunk szeretettel képzéseinken:</h3>
#   <a href="https://itbetyar.hu"><img alt="IT Betyár honlap" src="https://itbetyar.hu/dload_itb/colab_gomb_itb.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/python-tanfolyam/"><img alt="IT Betyár honlap" src="https://itbetyar.hu/dload_itb/colab_gomb_kpt.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/uzleti-a-i-automatizacio-workshop/"><img alt="IT Betyár honlap" src="https://itbetyar.hu/dload_itb/colab_gomb_aiaut.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/mesterseges-intelligencia-fejleszto-tanfolyam/"><img alt="AI Developer tanfolyam" src="https://itbetyar.hu/dload_itb/colab_gomb_aidev.webp" height="30px"></a>
#   <a href="https://itbetyar.hu/sql-tanfolyam/"><img alt="SQL Képzések" src="https://itbetyar.hu/dload_itb/colab_gomb_sql.webp" height="30px"></a>
#
# <h3>Social IT oldalak - Kód kohók:</h3>
#   <a href="https://huggingface.co/itbetyar"><img alt="Hugging Face oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_hugging.webp" height="30px"></a>
#   <a href="https://github.com/itbetyar"><img alt="Github oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_github.webp" height="30px"></a>
#   <a href="https://www.kaggle.com/itbetyar"><img alt="Kaggle oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_kaggle.webp" height="30px"></a>
#   <a href="https://www.youtube.com/@itbetyar"><img alt="Kaggle oldalunk" src="https://itbetyar.hu/dload_itb/colab_gomb_youtube.webp" height="30px"></a>
# </div>
# <br>
